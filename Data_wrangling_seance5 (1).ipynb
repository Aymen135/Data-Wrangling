# %% [markdown]
# 1) importer pandas, charger le fichier "courruption.csv" et afficher le dataframe df

# %%
import pandas as pd
data=pd.read_csv("corruption.csv")
data
# Out:
#            Country                        Region  2016  2015  2014  2013  2012
# 0      New Zealand                  Asia Pacific    90  88.0  91.0  91.0  90.0
# 1          Denmark       Europe and Central Asia    90  91.0  92.0  91.0  90.0
# 2          Finland       Europe and Central Asia    89  90.0  89.0  89.0  90.0
# 3           Sweden       Europe and Central Asia    88  89.0  87.0  89.0  88.0
# 4      Switzerland       Europe and Central Asia    86  86.0  86.0  85.0  86.0
# ..             ...                           ...   ...   ...   ...   ...   ...
# 170          Sudan            Sub-Saharan Africa    14  12.0  11.0  11.0  13.0
# 171          Syria  Middle East and North Africa    13  18.0  20.0  17.0  26.0
# 172  Korea (North)                  Asia Pacific    12   8.0   8.0   8.0   8.0
# 173    South Sudan            Sub-Saharan Africa    11  15.0  15.0  14.0   NaN
# 174        Somalia            Sub-Saharan Africa    10   8.0   8.0   8.0   8.0
#
# [175 rows x 7 columns]

# %% [markdown]
# 2) Verifier l'existence de valeurs

# %%
data.isnull().sum()
# Out:
# Country    0
# Region     0
# 2016       0
# 2015       9
# 2014       5
# 2013       3
# 2012       4
# dtype: int64

# %% [markdown]
# 3) Vérifier l'existence de valeurs abbérantes pour chaque Année (tracer boxplot)

# %%
import seaborn as sns

# %%
sns.set(style='whitegrid')
an=sns.boxplot(data=data,orient='v')

# %% [markdown]
# 4) Dans df1, copier le dataframe df et remplacer les valeurs nulles par la moyenne des valeurs de chaque pays

# %%
df1=data
df1
# Out:
#            Country                        Region  2016  2015  2014  2013  2012
# 0      New Zealand                  Asia Pacific    90  88.0  91.0  91.0  90.0
# 1          Denmark       Europe and Central Asia    90  91.0  92.0  91.0  90.0
# 2          Finland       Europe and Central Asia    89  90.0  89.0  89.0  90.0
# 3           Sweden       Europe and Central Asia    88  89.0  87.0  89.0  88.0
# 4      Switzerland       Europe and Central Asia    86  86.0  86.0  85.0  86.0
# ..             ...                           ...   ...   ...   ...   ...   ...
# 170          Sudan            Sub-Saharan Africa    14  12.0  11.0  11.0  13.0
# 171          Syria  Middle East and North Africa    13  18.0  20.0  17.0  26.0
# 172  Korea (North)                  Asia Pacific    12   8.0   8.0   8.0   8.0
# 173    South Sudan            Sub-Saharan Africa    11  15.0  15.0  14.0   NaN
# 174        Somalia            Sub-Saharan Africa    10   8.0   8.0   8.0   8.0
#
# [175 rows x 7 columns]

# %%
df1=df1.T
df1=df1.apply(lambda x : x.fillna(x.iloc[2:].mean()))
df1=df1.T
df1
# Out:
#            Country                        Region 2016  2015  2014  2013   2012
# 0      New Zealand                  Asia Pacific   90  88.0  91.0  91.0   90.0
# 1          Denmark       Europe and Central Asia   90  91.0  92.0  91.0   90.0
# 2          Finland       Europe and Central Asia   89  90.0  89.0  89.0   90.0
# 3           Sweden       Europe and Central Asia   88  89.0  87.0  89.0   88.0
# 4      Switzerland       Europe and Central Asia   86  86.0  86.0  85.0   86.0
# ..             ...                           ...  ...   ...   ...   ...    ...
# 170          Sudan            Sub-Saharan Africa   14  12.0  11.0  11.0   13.0
# 171          Syria  Middle East and North Africa   13  18.0  20.0  17.0   26.0
# 172  Korea (North)                  Asia Pacific   12   8.0   8.0   8.0    8.0
# 173    South Sudan            Sub-Saharan Africa   11  15.0  15.0  14.0  13.75
# 174        Somalia            Sub-Saharan Africa   10   8.0   8.0   8.0    8.0
#
# [175 rows x 7 columns]

# %%
df1.isnull().sum()
# Out:
# Country    0
# Region     0
# 2016       0
# 2015       0
# 2014       0
# 2013       0
# 2012       0
# dtype: int64

# %% [markdown]
# 5) Dans df2, afficher pour la Region "Middle East and North Africa" les 2 pays qui ont la somme des indices (2012 --> 2016) les moins et les plus élevés

# %%
data = df1.query(" Region=='Middle East and North Africa'").filter(["Country","2012","2013","2014","2015","2016"])
df2=pd.melt(data,id_vars=["Country"],var_name='year', value_name="CPI")
df2
# Out:
#                  Country  year   CPI
# 0   United Arab Emirates  2012  68.0
# 1                  Qatar  2012  68.0
# 2                 Jordan  2012  48.0
# 3           Saudi Arabia  2012  44.0
# 4                   Oman  2012  47.0
# ..                   ...   ...   ...
# 80               Lebanon  2016    28
# 81                  Iraq  2016    17
# 82                 Libya  2016    14
# 83                 Yemen  2016    14
# 84                 Syria  2016    13
#
# [85 rows x 3 columns]

# %%
datafinale=df2.drop(["year"],axis=1)

# %%
dataff=datafinale.groupby(["Country"]).sum()
dataff.sort_values(by='CPI', inplace=True)
dataff.iloc[[0,-1],:]
# Out:
#                         CPI
# Country
# Iraq                   83.0
# United Arab Emirates  343.0

# %% [markdown]
# 6) Dans df3, afficher pour chaque région et pour chaque Année, les pays (country et indice de corruption) qui ont l'indice de corruption les moins et les plus élevés.

# %%
df31=df1.melt(id_vars=["Region","Country"],var_name='year', value_name="CPI")
data4=df31.sort_values("CPI").groupby(["Region","year"]).nth([0,-1])

data4
# Out:
#                                                 Country   CPI
# Region                       year
# Americas                     2012             Venezuela  19.0
#                              2012                Canada  84.0
#                              2013                 Haiti  19.0
#                              2013                Canada  81.0
#                              2014                 Haiti  19.0
#                              2014                Canada  81.0
#                              2015                 Haiti  17.0
#                              2015                Canada  83.0
#                              2016             Venezuela    17
#                              2016                Canada    82
# Asia Pacific                 2012         Korea (North)   8.0
#                              2012           New Zealand  90.0
#                              2013         Korea (North)   8.0
#                              2013           New Zealand  91.0
#                              2014         Korea (North)   8.0
#                              2014           New Zealand  91.0
#                              2015         Korea (North)   8.0
#                              2015           New Zealand  88.0
#                              2016         Korea (North)    12
#                              2016           New Zealand    90
# Europe and Central Asia      2012          Turkmenistan  17.0
#                              2012               Denmark  90.0
#                              2013          Turkmenistan  17.0
#                              2013               Denmark  91.0
#                              2014          Turkmenistan  17.0
#                              2014               Denmark  92.0
#                              2015          Turkmenistan  18.0
#                              2015               Denmark  91.0
#                              2016            Uzbekistan    21
#                              2016               Denmark    90
# Middle East and North Africa 2012                  Iraq  18.0
#                              2012                 Qatar  68.0
#                              2013                 Libya  15.0
#                              2013  United Arab Emirates  69.0
#                              2014                  Iraq  16.0
#                              2014  United Arab Emirates  70.0
#                              2015                  Iraq  16.0
#                              2015                 Qatar  71.0
#                              2016                 Syria    13
#                              2016  United Arab Emirates    66
# Sub-Saharan Africa           2012               Somalia   8.0
#                              2012              Botswana  65.0
#                              2013               Somalia   8.0
#                              2013              Botswana  64.0
#                              2014               Somalia   8.0
#                              2014              Botswana  63.0
#                              2015               Somalia   8.0
#                              2015              Botswana  63.0
#                              2016               Somalia    10
#                              2016              Botswana    60

# %%
# Out:
#                                                          CPI
# Region                       Year Country
# Americas                     2012 Canada                84.0
#                                   Venezuela             19.0
#                              2013 Canada                81.0
#                                   Haiti                 19.0
#                              2014 Canada                81.0
#                                   Haiti                 19.0
#                              2015 Canada                83.0
#                                   Haiti                 17.0
#                              2016 Canada                82.0
#                                   Venezuela             17.0
# Asia Pacific                 2012 Korea (North)          8.0
#                                   New Zealand           90.0
#                              2013 Korea (North)          8.0
#                                   New Zealand           91.0
#                              2014 Korea (North)          8.0
#                                   New Zealand           91.0
#                              2015 Korea (North)          8.0
#                                   New Zealand           88.0
#                              2016 Korea (North)         12.0
#                                   New Zealand           90.0
# Europe and Central Asia      2012 Denmark               90.0
#                                   Turkmenistan          17.0
#                              2013 Denmark               91.0
#                                   Turkmenistan          17.0
#                              2014 Denmark               92.0
#                                   Turkmenistan          17.0
#                              2015 Denmark               91.0
#                                   Turkmenistan          18.0
#                              2016 Denmark               90.0
#                                   Uzbekistan            21.0
# Middle East and North Africa 2012 Iraq                  18.0
#                                   Qatar                 68.0
#                              2013 Libya                 15.0
#                                   United Arab Emirates  69.0
#                              2014 Iraq                  16.0
#                                   United Arab Emirates  70.0
#                              2015 Iraq                  16.0
#                                   Qatar                 71.0
#                              2016 Syria                 13.0
#                                   United Arab Emirates  66.0
# Sub-Saharan Africa           2012 Botswana              65.0
#                                   Somalia                8.0
#                              2013 Botswana              64.0
#                                   Somalia                8.0
#                              2014 Botswana              63.0
#                                   Somalia                8.0
#                              2015 Botswana              63.0
#                                   Somalia                8.0
#                              2016 Botswana              60.0
#                                   Somalia               10.0

# %% [markdown]
# 7) A partir de df3, tracer sous forme de barres verticales les valeurs les moins et les plus élevées des indices de corruption pour la région "Middle East and North Africa"

# %%
data4=data4.reset_index()
data5=data4.query("Region=='Middle East and North Africa'").iloc[:,1:]

# %%
import matplotlib.pyplot as plt
hist=data5.pivot(index='year',columns='Country',values='CPI')
hist.plot.bar()
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# 8) A partir de df1, afficher sous forme de barres horizontales les 5 premiers pays (Top5) de la région "Middle East and North Africa" qui ont la somme de CPI les plus élevées.

# %% [markdown]
# 9) A partir de df1:
# * Garder seulement les 50 pays (Top 50) qui ont la somme des CPI les plus élevés (2012 --> 2016)
# * Tracer sous forme de secteur la répartition de ces pays par région

# %% [markdown]
# 10) A partir de df1, afficher pour chaque region, et  sous forme de barres horizontales empilés (stacked) les 2 pays qui ont la somme de CPI la plus élevée.
